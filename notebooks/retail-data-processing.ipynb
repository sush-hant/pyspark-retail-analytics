# %%
from pyspark.sql.functions import col, to_date, year, month, round,sum, desc,row_number
from pyspark.sql import Window

# %% [markdown]
# Read the CSV data from Azure Data Lake

# %%
df = spark.read.csv("/mnt/raw/merge_csv.csv", header=True, inferSchema=True)

# %%
df.count()
# Out:
# 1067371

# %% [markdown]
# #Data Cleaning and processing

# %% [markdown]
# renaming the column

# %%
df = df.withColumnRenamed('Customer ID', 'CustomerID')

# %% [markdown]
# In this data, InvoiceNo that start with “C” indicate canceled transactions​, so we are not considering the canceled transactions

# %%
df_filterd = df.filter(~col('Invoice').startswith('C'))

# %% [markdown]
# Droping rows with null or missing CustomerID

# %%
df_filterd = df_filterd.filter(col('CustomerID').isNotNull())

# %% [markdown]
# Filter out any records with non-positive Quantity or UnitPrice

# %%
df_filterd = df_filterd.filter((col('Quantity') > 0) & (col('Price') > 0))

# %%
df_filterd = df_filterd.dropDuplicates()

# %% [markdown]
# #  Feature Engineering

# %% [markdown]
# Converted InvoiceDate to a Spark timestamp, then extracted year, month as numeric columns

# %%
df_filterd = df_filterd.withColumn('InvoiceDate', to_date(col('InvoiceDate'), 'MM/d/yyyy H:mm'))

df_filterd = df_filterd.withColumn("Year", year(col("InvoiceDate"))) \
    .withColumn("Month", month(col("InvoiceDate")))

# %% [markdown]
# Calculated Revenue of each transaction

# %%
df_filterd = df_filterd.withColumn('Revenue', round(col('Quantity') * col('Price'),2))

# %% [markdown]
# # Aggregations and Window Functions

# %% [markdown]
# Monthly Revenue by Product

# %%
monthly_sales = df_filterd.groupBy('Year','Month','Stockcode','Description').agg(sum('Revenue').alias('TotalRevenue'))

# %%
display(monthly_sales)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Year</th><th>Month</th><th>Stockcode</th><th>Description</th><th>TotalRevenue</th></tr></thead><tbody><tr><td>2009</td><td>12</td><td>85014B</td><td>RED/WHITE DOTS RUFFLED UMBRELLA</td><td>5953.95</td></tr><tr><td>2010</td><td>3</td><td>22363</td><td>GLASS JAR MARMALADE </td><td>155.60000000000002</td></tr><tr><td>2010</td><td>4</td><td>47591C</td><td>BLUE FAIRY CAKE CHILD'S APRON</td><td>103.35</td></tr><tr><td>2010</td><td>4</td><td>21815</td><td>STAR  T-LIGHT HOLDER </td><td>17.4</td></tr><tr><td>2010</td><td>2</td><td>79323P</td><td>PINK CHERRY LIGHTS</td><td>1523.1</td></tr><tr><td>2010</td><td>2</td><td>37450</td><td>CERAMIC CAKE BOWL + HANGING CAKES</td><td>253.20000000000002</td></tr><tr><td>2010</td><td>4</td><td>21327</td><td>SKULLS WRITING SET </td><td>132.0</td></tr><tr><td>2010</td><td>5</td><td>22088</td><td>PAPER BUNTING COLOURED LACE</td><td>544.5</td></tr><tr><td>2010</td><td>6</td><td>22548</td><td>HEADS AND TAILS SPORTING FUN</td><td>111.25</td></tr><tr><td>2010</td><td>6</td><td>22464</td><td>HANGING METAL HEART LANTERN</td><td>870.1500000000001</td></tr><tr><td>2010</td><td>6</td><td>15056N</td><td>EDWARDIAN PARASOL NATURAL</td><td>3290.15</td></tr><tr><td>2009</td><td>12</td><td>21341</td><td